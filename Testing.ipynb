# %%
from google.colab import drive
import os
ROOT = '/content/drive'
print(ROOT)
drive.mount(ROOT)
# Out:
# /content/drive
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# Clone github repository setup
# import join used to join ROOT path and MY_GOOGLE_DRIVE_PATH
from os.path import join  

# path to your project on Google Drive
MY_GOOGLE_DRIVE_PATH = 'My Drive/colab_nbs/tutorials' 
# replace with your Github username 
GIT_USERNAME = "mxgo111" 
# definitely replace with your
GIT_TOKEN = "a19dd24ba2dba0153afa1cde1ec83af613013a10"  
# Replace with your github repository in this case we want 
# to clone deep-learning-v2-pytorch repository
GIT_REPOSITORY = "deep-learning-v2-pytorch"

PROJECT_PATH = join(ROOT, MY_GOOGLE_DRIVE_PATH)

# It's good to print out the value if you are not sure 
print("PROJECT_PATH: ", PROJECT_PATH)   

# In case we haven't created the folder already; we will create a folder in the project path 
# !mkdir "{PROJECT_PATH}"    

#GIT_PATH = "https://{GIT_TOKEN}@github.com/{GIT_USERNAME}/{GIT_REPOSITORY}.git" this return 400 Bad Request for me
GIT_PATH = "https://" + GIT_TOKEN + "@github.com/" + GIT_USERNAME + "/" + GIT_REPOSITORY + ".git"
print("GIT_PATH: ", GIT_PATH)
# Out:
# PROJECT_PATH:  /content/drive/My Drive/colab_nbs/tutorials
# mkdir: cannot create directory ‘/content/drive/My Drive/colab_nbs/tutorials’: File exists
# GIT_PATH:  https://a19dd24ba2dba0153afa1cde1ec83af613013a10@github.com/mxgo111/deep-learning-v2-pytorch.git

# %%
# %cd /content/drive/My Drive/colab_nbs/tutorials
# !git clone https://a19dd24ba2dba0153afa1cde1ec83af613013a10@github.com/mxgo111/deep-learning-v2-pytorch.git
# Out:
# /content/drive/My Drive/colab_nbs/udacity_DL_pytorch
# fatal: destination path 'deep-learning-v2-pytorch' already exists and is not an empty directory.

# %%
# %cd /content/drive/My Drive/colab_nbs/tutorials/deep-learning-v2-pytorch
# Out:
# /content/drive/My Drive/colab_nbs/tutorials/deep-learning-v2-pytorch

# %%
# !git branch
# Out:
# * master
#   test

# %%
# !git ceh test
